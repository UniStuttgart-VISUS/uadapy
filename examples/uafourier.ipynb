# %%
# Debugging
import uadapy.data as data
from uadapy import TimeSeries
import uadapy.temporal.spectralAnalysis as spectralAnalysis
from uadapy.plotting.plots_timeseries import plot_timeseries
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Evers\Documents\Software\uadapy\venv\Lib\site-packages\chi2comb\__init__.py:53
#      52 try:
# ---> 53     from ._ffi import ffi
#      55     del ffi
#
# ImportError: DLL load failed while importing _ffi: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 4
#       2 import uadapy.data as data
#       3 from uadapy import TimeSeries
# ----> 4 import uadapy.temporal.spectralAnalysis as spectralAnalysis
#       5 from uadapy.plotting.plots_timeseries import plot_timeseries
#
# File c:\Users\Evers\Documents\Software\uadapy\venv\Lib\site-packages\uadapy\temporal\spectralAnalysis.py:6
#       4 import uadapy.distributions.chi_square_comb as chi_square_comb
# ...

# %% [markdown]
# # Loading data
# We provide ready-to-use toy datasets for quick experimentation and analysis. In this example, we use a synthetic dataset consisting of components with different periods, a trend and noise.

# %%
timeseries = data.generate_synthetic_timeseries(timesteps=200)

# %% [markdown]
# # Visualize the data

# %%
fig, axs = plot_timeseries(timeseries, n_samples=3, seed=55, show_plot=True)

# %% [markdown]
# # Computing the uncertain Fourier spectrum
# The uncertain Fourier spectrum can be computed directly from the input time series. We normalize the time series to avoid a large signal at a frequency of 0.

# %%
ua_spectrum = spectralAnalysis.ua_fourier_spectrum(timeseries, normalized=False)

# %% [markdown]
# # Show the Fourier spectrum
# As the distribution of the spectrum does not follow a normal distribution anymore, we show the median and the percentiles.

# %%
print(ua_spectrum.timesteps.shape)
plot_timeseries(ua_spectrum, n_samples=3, seed=55, percentiles=True, show_plot=True, x_label='Frequency')
# Out:
# (100,)
# 100
# 28464.91373037135
# (<Figure size 1500x300 with 1 Axes>,
#  <Axes: xlabel='Frequency', ylabel='value'>)
