# %%
# Debugging
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import uadapy.data as data
from uadapy import TimeSeries
import uadapy.temporal.spectralAnalysis as spectralAnalysis
from uadapy.plotting.plotsTimeSeries import plot_timeseries
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 10
#       8 import uadapy.data as data
#       9 from uadapy import TimeSeries
# ---> 10 import uadapy.temporal.spectralAnalysis as spectralAnalysis
#      11 from uadapy.plotting.plotsTimeSeries import plot_timeseries
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\__init__.py:1
# ----> 1 from .spectralAnalysis import *
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\spectralAnalysis.py:5
#       3 import math
#       4 import uadapy.distributions.chi_square_comb as chi_square_comb
# ----> 5 from chi2comb import chi2comb_cdf, ChiSquared
#       6 import scipy.optimize as optimize
#       8 def _fourier(i, j, N):
#
# ModuleNotFoundError: No module named 'chi2comb'

# %% [markdown]
# # Loading data
# We provide ready-to-use toy datasets for quick experimentation and analysis. In this example, we use a synthetic dataset consisting of components with different periods, a trend and noise.

# %%
timeseries = data.generate_synthetic_timeseries(timesteps=200)

# %% [markdown]
# # Visualize the data

# %%
fig, axs = plot_timeseries(timeseries, n_samples=3, seed=55, show_plot=True)

# %% [markdown]
# # Computing the uncertain Fourier spectrum
# The uncertain Fourier spectrum can be computed directly from the input time series.

# %%
ua_spectrum = spectralAnalysis.ua_fourier_spectrum(timeseries)

# %% [markdown]
# # Show the Fourier spectrum
# As the distribution of the spectrum does not follow a normal distribution anymore, we show the median and the percentiles.

# %%
# plot_timeseries(ua_spectrum, n_samples=3, seed=55, percentiles=True, show_plot=True)
# Out:
# (200,)
# (200, 200)
# float64
# 100
# (200,)
# Did not work for 2.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\spectralAnalysis.py:167, in _get_percentiles(l1, l2, b1, b2, min, max, p)
#     166 try:
# --> 167   res[i] = optimize.bisect(lambda x: cdfVal(x) - percentile, min, max)#, rtol=0.000001)
#     168 except:
#
# NameError: name 'optimize' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 plot_timeseries(ua_spectrum, n_samples=3, seed=55, percentiles=True, show_plot=True)
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\plotting\plotsTimeSeries.py:301, in plot_timeseries(timeseries, n_samples, percentiles, seed, fig, axs, colorblind_safe, show_plot)
#     299     y['light_band'] = [mu - 2.575829*np.sqrt(np.maximum(np.diag(sigma), 0)), mu + 2.575829*np.sqrt(np.maximum(np.diag(sigma), 0))]#sigma
#     300 else:
# --> 301     p2_5, p25, median, p75, p97_5 = compute_percentiles_complex(timeseries, [2.5, 25, 50, 75, 97.5])
#     302     y['light_band'] = [p2_5, p97_5]
#     303     y['dark_band'] = [p25, p75]
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\spectralAnalysis.py:101, in compute_percentiles_complex(timeseries, p)
#      99 d = np.diagonal(0.5 * np.real(gamma - c))
#     100 b = np.diagonal(0.5 * np.imag(gamma + c))
# --> 101 return _compute_percentiles_diagonals(mu_re, mu_im, a, b, d, p)
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\spectralAnalysis.py:140, in _compute_percentiles_diagonals(mu1, mu2, a, b, d, p)
#     138     b1 = (mu1 * p11 + mu2 * p12) / np.sqrt(l1)
#     139     b2 = (mu1 * p21 + mu2 * p22) / np.sqrt(l2)
# --> 140 return _percentiles_over_time(l1, l2, b1, b2, min=0, max=max(1000, np.max((mu1**2+mu2**2)*10)), p=p)
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\spectralAnalysis.py:152, in _percentiles_over_time(l1, l2, b1, b2, min, max, p)
#     150 # Iterate over each set of parameters and compute the percentiles
#     151 for i, (l1, l2, b1, b2) in enumerate(zip(l1, l2, b1, b2)):
# --> 152     percentiles[:,i] = _get_percentiles(l1, l2, b1, b2, min=min, max=max, p=p)
#     153 return percentiles
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\spectralAnalysis.py:170, in _get_percentiles(l1, l2, b1, b2, min, max, p)
#     168     except:
#     169       print("Did not work for " + str(percentile))
# --> 170       print(str(cdfVal(min)) + " " + str(cdfVal(max)))
#     171 return res
#
# File c:\Users\Marina\Desktop\uadapy\uadapy\temporal\spectralAnalysis.py:161, in _get_percentiles.<locals>.<lambda>(x)
#     159         cdfVal = lambda x: 0
#     160     else:
# --> 161         cdfVal = lambda x: cdfSingular(x, l=l1, b=b1, c=b2)
#     162 else:
#     163     cdfVal = lambda x: cdf(x, l1=l1, l2=l2, b1=b1, b2=b2)
#
# NameError: name 'cdfSingular' is not defined
