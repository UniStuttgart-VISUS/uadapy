# %%
# Ensure imports work when running from examples/ directory
import sys
import os
if os.getcwd().endswith('examples'):
    sys.path.insert(0, os.path.abspath('..'))

import uadapy
from uadapy import Distribution
import uadapy.data as data
import uadapy.dr.uapca as uapca
import uadapy.dr.wgmm_uapca as wgmm_uapca
from uadapy.plotting.plots_2d import plot_contour, plot_contour_bands, plot_samples
from uadapy.plotting.plots_nd import plot_contour as plot_contour_nd, plot_samples as plot_samples_nd, plot_contour_samples as plot_contour_samples_nd

# %% [markdown]
# ## Iris dataset as class-conditional distributions (KDE-based)

# %%
distribs_hi = data.load_iris()
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=True)

# %% [markdown]
# ## Iris dataset as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.load_iris_normal()
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=True)

# %% [markdown]
# ## Student grade dataset, sampled and then KDE fitted

# %%
import numpy as np
distribs_hi = data.load_student_grades(n_samples_per_student=1000, random_state=np.random.default_rng(42))
fig, axs = plot_contour_samples_nd(distribs_hi, n_samples=100, n_samples_kde=1000)
fig.set_size_inches(10,10)
fig;

# %%
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=False)
axs.set_aspect('equal', adjustable='datalim')
fig;

# %% [markdown]
# ## Wine dataset as class-conditional distributions (KDE-based)

# %%
distribs_hi = data.load_wine()
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour(distribs_lo, quantiles=[50, 95], show_plot=True)

# %% [markdown]
# ## Wine dataset as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.load_wine_normal()
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour(distribs_lo, quantiles=[50, 95], show_plot=True)

# %% [markdown]
# ## Breast Cancer Wisconsin dataset as class-conditional distributions (KDE-based)

# %%
distribs_hi = data.load_breast_cancer()
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour(distribs_lo, quantiles=[25, 75, 95, 99.9], show_plot=True)

# %% [markdown]
# ## Breast Cancer Wisconsin dataset as multivariate Normal distributions

# %%
distribs_hi = data.load_breast_cancer_normal()
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=True)

# %% [markdown]
# ## Digits dataset as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.load_digits_normal()
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_samples_nd(distribs_lo, n_samples=2000, point_size=1, show_plot=True)

# %% [markdown]
# ## Forest Cover Type dataset as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.fetch_covtype_distributions_normal()
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_samples_nd(distribs_lo, n_samples=2000, point_size=1, show_plot=True)

# %% [markdown]
# ## Gaussian blobs as class-conditional distributions (KDE-based)

# %%
distribs_hi = data.make_blobs_distributions(n_samples=1500, centers=3, n_features=2)
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=True)

# %% [markdown]
# ## Gaussian blobs as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.make_blobs_distributions_normal(centers=4, cluster_std=1.2)
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=True)

# %% [markdown]
# ## Two moons dataset as class-conditional distributions (KDE-based)

# %%
distribs_hi = data.make_moons_distributions(n_samples=2000, noise=0.15)
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=True)

# %% [markdown]
# ## Two moons dataset as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.make_moons_distributions_normal(noise=0.2)
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour(distribs_lo, show_plot=True)

# %% [markdown]
# ## Concentric circles as class-conditional distributions (KDE-based)

# %%
distribs_hi = data.make_circles_distributions(n_samples=2000, noise=0.1, factor=0.5)
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_bands(distribs_lo, show_plot=True)

# %% [markdown]
# ## Concentric circles as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.make_circles_distributions_normal(noise=0.05)
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour(distribs_lo, show_plot=True)

# %% [markdown]
# ## Gaussian-quantiles data as class-conditional distributions (KDE-based)

# %%
distribs_hi = data.make_gaussian_quantiles_data(n_samples=2000, n_features=2, n_classes=3)
distribs_hi = [Distribution(uadapy.distributions.gmm_from_kde(d.kde)) for d in distribs_hi]
distribs_lo = wgmm_uapca(distribs_hi, n_dims=2)
fig, axs = plot_samples(distribs_lo, n_samples=2000, point_size=4, show_plot=True)

# %% [markdown]
# ## Gaussian-quantiles data as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.make_gaussian_quantiles_normal(n_classes=4, cov=1.2)
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_nd(distribs_lo, n_samples_kde=1000, quantiles=[75, 90], show_plot=True)

# %% [markdown]
# ## Synthetic classification problem as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.make_classification_distributions_normal()
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour(distribs_lo, quantiles=[50, 95], show_plot=True)

# %% [markdown]
# ## Hastie 10-2 dataset as class-conditional multivariate Normal distributions

# %%
distribs_hi = data.make_hastie_10_2_distributions_normal()
distribs_lo = uapca(distribs_hi, n_dims=2)
fig, axs = plot_contour_nd(distribs_lo, n_samples_kde=1000, quantiles=[75, 90], show_plot=True)
